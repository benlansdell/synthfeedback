# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('/home/prashanth/synthfeedback/experiments/WM_4layer/summary/WM_4layer(condnum).npz','rb') as f:
    data=pickle.load(f,encoding='latin1')

# %%
print("learnng_rate_b:",data['learning_rate_b'],"learning_rate:",data['learning_rate'],"lamba",data['lamba'])
# Out:
# learnng_rate_b: [0.07324342168056529, 0.059138103939764694, 3.917030294267885e-05, 0.012299622056571475, 0.005731699685484604, 8.87052263951363e-05, 0.00035710318293545005, 1.1678510543653897e-05, 0.000573797391940226] learning_rate: [1.1355598737663961e-05, 0.0015473576864341062, 0.00012320127738473324, 0.00013410040294339245, 0.0016495031744571144, 0.00650687455330452, 0.0008062394401402257, 0.011417398700466876, 0.0005472265780159301] lamba [0.050024546499919505, 0.036696566900414805, 0.020119269339068276, 0.0476506396556148, 0.014115752778044492, 0.02906592442601305, 0.03428415281460931, 0.03137522484340843, 0.08772463766937376]

# %%
len(data['learning_rate_b'])
# Out:
# 9

# %% [markdown]
# # Results for weight mirror in a 4 layered network and zero learning rate

# %% [markdown]
# Parameters:
# batch size=32
# Epochs=2000
# Iteration per epoch = 1000

# %%
data['metrics'].shape
# Out:
# (20, 1, 2001, 10)

# %%
for i in range(data['metrics'].shape[0]):
    store_acc=np.mean(data['metrics'][i,:,:,0],axis=0)
    leg="combo%d"%i
    plt.plot(store_acc,label=leg)
plt.legend()
plt.title("loss")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_loss=np.mean(data['metrics'][i,:,:,1],axis=0)
    leg="combo%d"%i
    plt.plot(store_loss,label=leg)

plt.legend()
plt.title("acc")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_loss=np.mean(data['metrics'][i,:,:,2],axis=0)
    leg="combo%d"%i
    plt.semilogy(store_loss,label=leg)
plt.legend()
plt.title("loss_test")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_loss_tst=np.mean(data['metrics'][i,:,:,3],axis=0)
    leg="combo%d"%i
    plt.plot(store_loss_tst,label=leg)
plt.legend()
plt.title("acc_test")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_al_B2=np.mean(data['metrics'][i,:,:,4],axis=0)
    plt.plot(store_al_B2)
# plt.legend()
plt.title("Alignment B2")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_al_B3=np.mean(data['metrics'][i,:,:,5],axis=0)
    leg="combo%d"%i
    plt.plot(store_al_B3,label=leg)
plt.legend()
plt.title("Norm_W2-B2")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_al_B3=np.mean(data['metrics'][i,:,:,6],axis=0)
    leg="combo%d"%i
    plt.semilogy(store_al_B3,label=leg)
plt.legend()
plt.title("Norm gradB2")
plt.xlabel("Epoch")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_acc_tst=np.mean(data['metrics'][i,:,:,7],axis=0)
    leg="combo%d"%i
    plt.plot(store_acc_tst,label=leg)
plt.legend()
plt.title("Alignment_B3")
plt.xlabel("Epoch")
plt.show()

# %%
print(data['tags'])
# neuro_num=[30,100,300,1000]
# Out:
# ['loss', 'acc', 'loss_test', 'acc_test', 'align_B2', 'norm_W2_B2', 'norm_gradB2', 'align_B3', 'norm_W3_B3', 'norm_gradB3']

# %%
for i in range(data['metrics'].shape[0]):
    store_norm_W3B3=np.mean(data['metrics'][i,:,:,8],axis=0)
    leg="combo%d"%i
    plt.plot(store_norm_W3B3,label=leg)
plt.legend()
plt.title("Norm W3-B3")
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_norm_W2B2=np.mean(data['metrics'][i,:,:,9],axis=0)
    leg="combo%d"%i    
    plt.plot(store_norm_W2B2,label=leg)
plt.legend()
plt.title("Norm gradB3")
plt.show()
