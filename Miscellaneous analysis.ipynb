# %%
import tensorflow as tf 
import numpy as np
import matplotlib.pyplot as plt
import pickle

# %%
with open('/home/prashanth/synthfeedback/experiments/nodepert4_fixedw_exact/summary/2_establish_convergence_feedforward_output.npz','rb') as f:
    data=pickle.load(f)

# %%
print(data['tags'])
neuro_num=[500,1000,1500,2000]
# Out:
# ['acc', 'loss', 'loss_test', 'align_B2', 'align_B3', 'acc_test', 'norm_W3_B3', 'norm_W2_B2']

# %%
for i in range(data['metrics'].shape[0]):
    store_acc=np.mean(data['metrics'][i,:,:,0],axis=0)
    plt.plot(store_acc,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_loss=np.mean(data['metrics'][i,:,:,1],axis=0)
    plt.plot(store_loss,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_loss_tst=np.mean(data['metrics'][i,:,:,2],axis=0)
    plt.plot(store_loss_tst,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_al_B2=np.mean(data['metrics'][i,:,:,3],axis=0)
    plt.plot(store_al_B2,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_al_B3=np.mean(data['metrics'][i,:,:,4],axis=0)
    plt.plot(store_al_B3,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_acc_tst=np.mean(data['metrics'][i,:,:,5],axis=0)
    plt.plot(store_acc_tst,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_norm_W3B3=np.mean(data['metrics'][i,:,:,6],axis=0)
    plt.plot(store_norm_W3B3,label=neuro_num[i])
plt.legend()
plt.show()

# %%
for i in range(data['metrics'].shape[0]):
    store_norm_W2B2=np.mean(data['metrics'][i,:,:,7],axis=0)
    plt.plot(store_norm_W2B2,label=neuro_num[i])
plt.legend()
plt.show()
