# %%
# %matplotlib inline

import numpy as np
import matplotlib.pyplot as plt

# %%
#Load file
exp_name = 'feedbackalignment'
fn = '../experiments/%s/summary/train.npy'%exp_name
data = np.load(fn)

# %%
data
# Out:
# array([[ 1.73803635e+01,  1.17812499e-01, -1.59973111e-02,
#          4.43657494e+00,  7.25017319e+01,  2.34259720e+01],
#        [ 1.59589262e+01,  1.49375007e-01,  3.20474021e-02,
#          4.42776060e+00,  7.25017319e+01,  2.56856499e+01],
#        [ 1.40687981e+01,  3.02812487e-01, -6.06650934e-02,
#          4.42299366e+00,  7.25017319e+01,  2.24302807e+01],
#        ...,
#        [ 2.00428224e+00,  9.55937505e-01,  5.50135136e-01,
#          4.73015833e+00,  7.25017319e+01,  4.04292393e+00],
#        [ 2.05586720e+00,  9.52812493e-01,  5.38593888e-01,
#          4.73039627e+00,  7.25017319e+01,  4.25186634e+00],
#        [ 1.96651554e+00,  9.62499976e-01,  5.19866824e-01,
#          4.73077297e+00,  7.25017319e+01,  6.43698502e+00]])

# %%
#Rows = loss, acc, alignment, norm W, norm B, L2 error in feedback
plt.plot(data[:,0])

# %%
plt.plot(180/np.pi*np.arccos(data[:,2]))
plt.xlabel('epoch')
plt.ylabel('alignment (degrees)')
plt.ylim([0, 90])
# Out:
# (0, 90)
