# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"]='0'

import tensorflow as tf
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

import numpy as np
import numpy.random as rng
import pickle
import numpy as np
import matplotlib.pyplot as plt

import random
from utils.utils import tf_matmul_r, tf_matmul_l, tf_eigvecs, tf_eigvals
# Out:
# /opt/anaconda/miniconda2/envs/py35/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /opt/anaconda/miniconda2/envs/py35/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
with open('/home/prashanth/synthfeedback/Pickles/MNIST_NP.pkl','rb') as f:
    store_err,store_al,store_acc,iteration,noise=pickle.load(f,encoding='latin1')

# %%
store_acc.shape
# Out:
# (1, 10000)

# %%
store_acc
# Out:
# array([[ 0.2 ,  0.16,  0.08, ...,  0.1 ,  0.06,  0.06]])

# %%
plt.plot(store_acc[0])
plt.show()

# %%
print("Following are the noises tested for:\n")
for i in noise:
    print(i)
# Out:
# Following are the noises tested for:
#
# 0.0001
# 0.000398107170553
# 0.00158489319246
# 0.0063095734448
# 0.0251188643151
# 0.1

# %%
for i in range(noise.shape[0]):
    plt.plot(store_acc[i,:],label=noise[i])
plt.legend()
plt.show()

# %%
for i in range(noise.shape[0]):
    plt.plot(store_err[i,:],label=noise[i])
plt.legend()
plt.show()

# %%
for i in range(noise.shape[0]):
    plt.plot(np.degrees(np.arccos(store_al[i,:])),label=noise[i])
plt.legend()
plt.show()

# %%
store_al[i,:].shape
# Out:
# (100000,)
